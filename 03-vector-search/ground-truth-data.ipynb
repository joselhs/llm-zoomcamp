# %%
import requests 

docs_url = 'https://github.com/DataTalksClub/llm-zoomcamp/blob/main/01-intro/documents.json?raw=1'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

# %%
documents[1]
# Out:
# {'text': 'GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites',
#  'section': 'General course-related questions',
#  'question': 'Course - What are the prerequisites for this course?',
#  'course': 'data-engineering-zoomcamp'}

# %%
import hashlib

def generate_document_id(doc):
    combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}"
    hash_object = hashlib.md5(combined.encode())
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8]
    return document_id

# %%
n = len(documents)

for doc in documents:
    doc['id'] = generate_document_id(doc)

# %%
documents[3]
# Out:
# {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#  'section': 'General course-related questions',
#  'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#  'course': 'data-engineering-zoomcamp',
#  'id': '0bbf41ec'}

# %%
import json

with open('documents-with-ids.json', 'wt') as f_out:
    json.dump(documents, f_out, indent=2)

# %%
prompt_template = """
You emulate a student who's taking our course. 
Formulate 5 questions this student might ask based on a FAQ record.
The record should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record.

The record:

section: {section}
question: {question}
answer: {text}

Provide the output in a parsable JSON without using code blocks:

["question1", "question2", ..., "question5"]
""".strip()

# %%
from openai import OpenAI

client = OpenAI()

# %%
doc = documents[9]

prompt = prompt_template.format(**doc)

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content

    return json.loads(json_response)

# %%
json_response = generate_questions(doc)

# %%
from tqdm.auto import tqdm

# %%
results = {}

for doc in tqdm(documents):
    doc_id = doc['id']
    
    if doc_id in results:
        continue
        
    questions = generate_questions(doc)
    results[doc_id] = questions
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
final_results = []

for doc_id, questions in results.items():
    course = doc_index[doc_id]['course']
    for q in questions:
        final_results.append((q, course, doc_id))

# %%
for doc_id, questions in results.items():
    course = doc_index[doc_id]['course']
    print(questions)
# Out:
# [
#   "When is the start date and time for the course?",
#   "How can I subscribe to the course's Google Calendar?",
#   "Where do I register before the course begins?",
#   "How do I join the course's Telegram channel?",
#   "Should I register in DataTalks.Club's Slack for this course?"
# ]
# [
#   "Where can I find the prerequisites for this course?",
#   "What should I know before joining the course?",
#   "Is there a list of required skills for this course?",
#   "Can you point me to the course prerequisites?",
#   "What background knowledge is necessary for this course?"
# ]
# [
#   "Can I register for the course after it has already started?",
#   "Am I allowed to submit homework if I join the course late?",
#   "Are there deadlines for submitting final projects if I join late?",
#   "If I don’t register on time, can I still participate in the course?",
#   "What should I keep in mind if I join the course after it has begun?"
# ]
# [
#   "Is it necessary to wait for a confirmation email before starting the Data Engineering Bootcamp?",
#   "Do I need confirmation of registration to begin submitting homework in the course?",
#   "Is there any check against a registered list of students for starting the bootcamp?",
#   "What is the main purpose of the registration process for the Data Engineering Bootcamp?",
#   "Can I immediately begin learning in the bootcamp after registering?"
# ]
# [
#   "What preparations should I make before the course starts?",
#   "Which software and tools do I need to install before the course begins?",
#   "Which version of Python should I have installed for this course?",
#   "Do I need a Google Cloud account before the course starts?",
#   "Where can I find the prerequisites and syllabus for the course?"
# ]
# [
#   "How many Zoomcamps are conducted in a year?",
#   "When does the Data-Engineering Zoomcamp take place?",
#   "Can I join a Zoomcamp at any time if I'm not interested in the Certificate?",
#   "Is there more than one 'live' cohort for each Zoomcamp per year?",
#   "Are the schedules for the Zoomcamps consistent for each cohort every year?"
# ]
# ["Will the 2024 cohort use a different AI tool?",
# "Have the terraform videos been updated for the new cohort?",
# "Which AI tool was used in the 2023 cohort?",
# "Is Prefect still being utilized in the 2024 course?",
# "Are changes being made to the 2024 edition compared to 2023?"]
# [
#   "Can I still access the course materials after the course has ended?",
#   "Will the homeworks be available for review after the course is finished?",
#   "Can I complete the course at my own pace after it concludes?",
#   "Is it possible to keep preparing for the next cohort after the course ends?",
#   "Can I start working on my final capstone project after the course finishes?"
# ]
# ["Will I have access to support if I choose to take the course in self-paced mode?",
# "Where should I look first before asking questions on the Slack channel?",
# "What should I do if I can't find my answer in the Slack channel or the FAQ?",
# "Is there a bot available to help me search for answers, and how reliable is it?",
# "What is the recommended order of resources to check when I have a question about the course?"]
# [
#   "Which YouTube playlist contains the main videos for the course?",
#   "Where can I find each course video with a thumbnail?",
#   "Do I need to refer to any year-specific playlist for additional videos?",
#   "Where on Slack can I find the main playlist?",
#   "Is there a specified year for the main 'DATA ENGINEERING' playlist?"
# ]
# ["How many hours a week will this course take?", "What is the weekly time commitment for this course?", "Can you tell me the expected weekly hours for this course?", "How much time should I set aside weekly for the course?", "What is the weekly workload for someone starting this course?"]
# [
#   "Is it possible to receive a certificate if I complete the course at my own pace?",
#   "Do I need to be part of a live cohort to obtain a certificate?",
#   "Can I earn a certificate without participating in the live course sessions?",
#   "Why can't I get a certificate for completing the course self-paced?",
#   "What is required to peer-review the capstone projects for certification?"
# ]
# [
#   "Where can I find the video link for the office hour sessions?",
#   "How should students submit questions during the workshops?",
#   "In what platforms will the office hour session URLs be posted?",
#   "Why shouldn’t I post my questions in the YouTube Live chat during the sessions?",
#   "Who gets access to the Zoom link for the office hours?"
# ]
# ["Can I watch a recording of the Office Hours if I miss it?",
# "When will the recordings of the Office Hours be available?",
# "Are all workshops recorded for later viewing?",
# "Is it possible to rewatch the Office Hours sessions anytime?",
# "What happens if I can't attend the live Office Hours session?"]
# [
#   "Where can I locate the latest deadlines for homework and projects?",
#   "How will I be notified of any extensions to deadlines?",
#   "Are the deadlines in the Google spreadsheet always current?",
#   "Does @Au-Tomator announce all deadline-related updates?",
#   "Will the form itself show updated deadlines if they are changed?"
# ]
# ["Are late homework submissions permitted?", "What happens if I submit homework after the deadline?", "Can I still submit homework if the form is open past the due date?", "How can I confirm my homework submission?", "Are there any exceptions for late homework submissions?"]
# ["What is the homework URL for the assignments?", "Where should I store my homework code?", "Is my GitHub repository the correct homework URL?", "Can I use Bitbucket for submitting homework?", "What is an acceptable location for my code?"]
# ["How are homework assignments graded in the course management platform?", "Where can I see the points I've earned for each homework?", "What points are included on the leaderboard?", "How many points do I get for submitting to the FAQ?", "How many points do I receive for each Learning in Public link?"]
# ["How can I find out what my random display name on the leaderboard is?", "What is the link to access the homework submission page?", "Where do I need to go to see my display name?", "How can I change my display name for the course?", "Am I automatically assigned a display name when I set up my account?"]
# [
#     "Is Python 3.9 still recommended for use in 2024?",
#     "Can I use Python 3.10 for the course?",
#     "Will Python 3.11 work for the course?",
#     "Why is Python 3.9 suggested in 2024?",
#     "Is Python 3.9 preferred for troubleshooting?"
# ]
# ["Can I use my local machine to set up the course environment?",
#  "If I work locally from my laptop or PC, what should I do first?",
#  "What are the options if I face challenges working locally, especially on Windows?",
#  "Which platform allows me to work virtually anywhere given multiple devices?",
#  "What are the first steps if I prefer using GitHub Codespaces?"]
# ["Is GitHub Codespaces an alternative to using CLI/git bash for data ingestion?",
# "Does GitHub Codespaces offer pre-installed tools?",
# "Can I create a Docker file using GitHub Codespaces?",
# "Are Linux resources available on GitHub Codespaces?",
# "Is it possible to open any GitHub repository in a GitHub Codespace?"]
# ["Do I have to use GitHub codespaces for the course?",
# "Can I use my laptop instead of GitHub codespaces?",
# "Is GCP VM mandatory for the course?",
# "Can I complete the course without using a pre-specified environment?",
# "Are Github codespaces and GCP VM the only platforms allowed?"]
# [
#   "Do I need to use both GitHub Codespaces and GCP for this course?",
#   "Is it necessary to learn BigQuery as part of the course?",
#   "Can I complete most of the course using a local environment setup?",
#   "Which tool should I choose for my end project, GitHub Codespaces or GCP?",
#   "Would setting up a local environment be enough for this course?"
# ]
# ["How can I connect to a GCP VM using VSCode on a Windows machine?", "What are the steps to open the Run command window on a Windows machine?", "Where is the known_hosts file located in Windows?", "How do I change registry values in the Registry Editor?", "What registry key needs to be modified to solve the GCP VM connection issue?"]
# ["Why are we using GCP instead of other cloud providers?", "Are we allowed to use AWS or Azure for course projects?", "What benefits does GCP offer for new users?", "Do I need a credit card to sign up for a free GCP account?", "Why is BigQuery important for this course?"]
# ["Do I need to pay for cloud services for this course?", "Is there a cost associated with using GCP for this course?", "Can I utilize GCP free of charge during this course?", "Will I incur any cloud service fees in this course?", "Is using GCP free trial sufficient for the coursework?"]
# ["Is it necessary to use a cloud provider like GCP for this course?",
# "Can I complete the course without BigQuery?",
# "Is there a local alternative for everything in the course?",
# "Why can't you provide guidelines for some components?",
# "Can the entire course be done on a home lab?"]
# ["Can I use AWS for the course instead of the recommended tools?", "What should I adapt if I decide to use AWS?", "Will the final capstone project evaluation criteria change if I use AWS?", "What challenges might I face if I use AWS for the course?", "Where can I find additional help if I choose to use AWS and need assistance?"]
# [
#   "Will there be any live sessions aside from the Office Hour?",
#   "When will the Capstone period calls be announced?",
#   "Are live Zoom calls planned for periods other than the Capstone?",
#   "How will I know when a Zoom call is scheduled?",
#   "Is there a schedule for live calls during the Capstone?"
# ]
# [
#   "Are we using the NYC Trip data for January 2021 or 2022?",
#   "Is the project data for this year the same as last year’s?",
#   "Will the data source for our project be different from 2021?",
#   "Has the NYC Trip data been updated for 2022?",
#   "Is the dataset for our project unchanged from last year?"
# ]
# [
#   "Is the 2022 repository removed?",
#   "Where can I find the materials for 2022?",
#   "Have you deleted the 2022 content?",
#   "Is the 2022 stuff still available?",
#   "Are the 2022 resources relocated?"
# ]
# [
#   "Can I use a different tool for my project?",
#   "Is it allowed to choose any tool for the final project?",
#   "Am I restricted to specific tools for my project?",
#   "May I select Airflow for my final task?",
#   "Can I utilize my preferred tool for the project?"
# ]
# ["Can I use Airflow instead of Mage in the course?",
#  "Is it allowed to use AWS services instead of GCP products?",
#  "Can I choose Tableau over Metabase for this course?",
#  "If I use a different tool stack, will I receive support?",
#  "Do I need to explain my tool choices in the capstone project if I deviate from the recommended stack?"]
# [
#   "How can I help with the course?",
#   "What can I do to improve the course?",
#   "Is there a way to support the course?",
#   "How can I share this course with others?",
#   "Can I contribute to the course content?"
# ]
# [
#   "Which operating systems are compatible with this course?",
#   "Is it possible to use Windows for this course?",
#   "Can I complete the course on a Mac?",
#   "What operating system is recommended for this course?",
#   "Did students use different operating systems last year?"
# ]
# ["What should Windows users do when encountering *.sh scripts in later modules?",
#  "How did past students handle the issue with shell scripts on Windows?",
#  "Is there a way to run *.sh files on Windows without WSL?",
#  "Why is WSL recommended for this course from the beginning?",
#  "Which modules specifically require the use of shell scripts?"]
# [
#   "Where can I find recommended books or additional resources for the course?",
#   "Do you suggest any extra reading material for the course?",
#   "Is there a document that lists useful books and resources for this course?",
#   "Are there particular resources you recommend for further learning?",
#   "Can you provide a link to recommended books and resources for the course?"
# ]
# [
#   "What does Project Attempt #1 and Project Attempt #2 mean?",
#   "Can I submit my project after the first deadline is over?",
#   "Do I get another chance if I fail the first project submission?",
#   "What happens if I miss the first project deadline?",
#   "Is there a second opportunity to submit a project after failing the first attempt?"
# ]
# ["What should be my first step when troubleshooting an issue?", "What is a useful shortcut for finding specific information in documentation or code?", "How can I find out if there is already a solution for a problem I am facing?", "What should I do before asking a question in Slack?", "Why should I avoid using screenshots when asking for help?"]
# ["When do I need to ask a question?", "What details should I include when asking a question?", "How should I describe the error encountered when asking a question?", "Why is it important to mention what I've tried that didn't work?", "What should I do before asking a question?"]
# [
#   "How do I clone the course repository from GitHub to my local machine?",
#   "Where can I learn how to create my own GitHub repositories for my notes and files?",
#   "What types of files should I avoid saving to a Git repository for this course?",
#   "How can I ensure sensitive information like passwords is not stored in my GitHub repository?",
#   "What video resource outlines the process of cloning a GitHub repository?"
# ]
# [
#   "What should I do if I encounter an error about a missing separator in a Makefile?",
#   "How do I resolve the Makefile:2: *** missing separator. Stop. error in VS Code?",
#   "Why do I get a missing separator error in my Makefile when using VS Code?",
#   "What's the solution to the Makefile error that mentions *** missing separator?",
#   "If spaces cause a Makefile error in VS Code, how can I fix it?"
# ]
# ["How can I open an HTML file with a Windows browser from Linux running on WSL?",
#  "What steps should I take to open a web page using wslview?",
#  "How do I set a specific Windows browser to open HTML files from WSL?",
#  "Which tool is needed to open an HTML file from Linux on Windows using WSL?",
#  "Can I customize the browser used for opening HTML files on WSL and how?"]
# ["How can I set up Chrome Remote Desktop on a Debian Linux VM in Compute Engine?",
# "What tool is recommended for unzipping the 'gz' file downloaded from the backup link?",
# "What error do you encounter when downloading the 2021 Yellow Taxi Trip Records from the TLC website?",
# "Is there a backup available for the 2021 Yellow Taxi Trip Records and what is the link?",
# "What should one do if they see 'ERROR 403: Forbidden' when clicking the link to download taxi data from the TLC site?"]
# [
#   "How should I handle taxi data files that are available as *.csv.gz in Module 1 of the Docker and Terraform course?",
#   "Why doesn’t the data file store correctly if the extension is csv.gz instead of csv in Module 1?",
#   "What is the URL for the yellow taxi data file in Module 1 of the Docker and Terraform course?",
#   "How can we dynamically replace 'csv_name' in the code used in Module 1 to correctly read taxi data files with a csv.gz extension?",
#   "Can the pandas read_csv function handle files with a csv.gz extension directly in Module 1?"
# ]
# [
#   "Where can I find the data dictionary for Yellow Taxi trip records in NYC?",
#   "Is there a data dictionary available for Green Taxi trips in NYC?",
#   "How can I access the documentation for Yellow Taxi data in Module 1?",
#   "Where is the data dictionary for Green Taxi trip records provided in Module 1?",
#   "What is the URL for the Yellow Taxi trips data dictionary mentioned in the course?"
# ]
# [
#   "How can I unzip a downloaded parquet file in Module 1 of the Docker and Terraform course?",
#   "What command should I use to convert a .parquet file to a .csv file in the ingest_data.py script?",
#   "Which line should be added in the def main(params) function to handle parquet files directly in Python?",
#   "How do I download a parquet file using wget and store it with a specific name in the Docker and Terraform course?",
#   "What is the correct way to convert a .parquet file to .csv and save it with a relevant name in the ingest_data.py script?"
# ]
# ["How do I resolve 'wget is not recognized as an internal or external command' error on Ubuntu?", "Which command should I use to install wget on MacOS?", "What is the recommended method to install wget on Windows?", "How can I use wget on Windows if I don't want to use Chocolatey?", "What Python library can be used as an alternative to wget?"]
# ["What should you add before wget when using Jupyter Notebook or CLI on MacOS?", "What Python library can be used if wget is not working due to a certificate error?", "How do you modify the wget command to bypass certificate verification?", "How should you modify the wget command in CLI to avoid certificate issues?", "What is the role of --no-check-certificate in a wget command?"]
# {
#   "question1": "How do I make the backslash an escape character in Git Bash for Windows?",
#   "question2": "What terminal command allows backslash to be used as an escape character in Git Bash?",
#   "question3": "Do I need to include the backslash escape character setting in .bashrc for Git Bash?",
#   "question4": "Which shell configuration does Alexey typically use for backslash escaping in Git Bash?",
#   "question5": "Can you provide the command to set the backslash as an escape character in Git Bash?"
# }
# ["How can I store secrets in GitHub Codespaces?", "Where can I find instructions for managing secrets specific to my account on GitHub Codespaces?", "What is the process for handling account-specific secrets in GitHub Codespaces?", "Are there any guidelines for storing secrets available in GitHub Codespaces?", "Where in the GitHub Docs can I learn about storing secrets for Codespaces?"]
# ["How can I resolve the error 'Cannot connect to Docker daemon at unix:///var/run/docker.sock'?", "What do I do if Docker cannot connect to the daemon?", "How do I start the Docker daemon to fix connection issues?", "What is the solution for Docker daemon connection problems on Unix?", "How can I check if the Docker daemon is running in Unix?"]
# ["What should Windows 10 Pro/11 Pro users do to use Docker with Hyper-V as backend?", "Can Windows 10 Home/11 Home users use Hyper-V for Docker?", "What backend option is available for Docker on Windows 10 Home/11 Home?", "Where can I find detailed instructions for installing WSL2 on Windows 11?", "What should I do if I encounter the error 'WslRegisterDistribution failed with error: 0x800701bc' while installing WSL2?"]
# {
#   "questions": [
#     "What should I do if I receive an error stating 'repository does not exist or may require docker login' when using docker pull?",
#     "How can I resolve Docker's 'permission denied' error when creating a PostgreSQL container with a mounted volume on macOS M1?",
#     "Do I need to perform a docker login to fetch the Docker images used in the Data Engineering Zoomcamp?",
#     "What should I do if I get the error 'requested access to the resource is denied' while using docker pull?",
#     "What steps should I follow to create PostgreSQL containers with mounted volumes for the New York Taxi Database on macOS M1?"
#   ]
# }
# [
#   "How can I delete a local folder mounted to a Docker volume that has write and read protection?",
#   "What user owns the folder created on my local machine when using Docker to create a PostgreSQL container?",
#   "Why couldn't I delete the Docker-mounted folder by simply dragging it to the trash?",
#   "What command can be used to forcefully delete a protected folder created by Docker on a local machine?",
#   "What are the specific flags used in the command for deleting the Docker-created folder, and what do they mean?"
# ]
# [
#   "How do I fix Docker if it's stuck in settings or won't start on Windows 10 or 11?",
#   "Is there a download link for the latest version of Docker for Windows?",
#   "What should I do if Docker is stuck on starting?",
#   "Can Windows 10 or 11 Pro Edition run Docker using Hyper-V or WSL2?",
#   "How do I enable Hyper-V on Windows 10 or 11?"
# ]
# ["Is it advisable to run Docker commands from Windows file system or WSL Linux distribution?", "What edition of Windows is required to make Docker work with WSL2?", "Where can I find a tutorial to set up Docker with WSL2 on Windows Home Edition?", "What should I do if Docker remains stuck even after properly setting up WSL2 or Hyper-V?", "Is there an alternative solution if resetting Docker to factory defaults does not solve the issue?"]
# {
#   "question1": "Why should I store all my code in my default Linux distro when using Docker?",
#   "question2": "Which operating systems use the WSL2 backend for Docker by default?",
#   "question3": "Where can I find more information on Docker best practices?",
#   "question4": "In which module can I learn about Docker and Terraform?",
#   "question5": "Is Docker's WSL2 backend the default for Windows 10 Home users?"
# }
# ["What can I do if I receive 'the input device is not a TTY' error while running Docker on Windows?", "How should I prefix my Docker command to solve the input device is not a TTY error?", "Is there a way to avoid typing 'winpty' every time I run a Docker command?", "How do I create an alias for Docker to always use 'winpty' on Windows?", "Can I use both .bashrc and .bash_profile to set up a Docker alias?"]
# ["What might cause a 'Temporary failure in name resolution' error when trying to pip install on a Docker container in Windows?", "What error message might I see related to 'NewConnectionError' when pip install fails in a Docker container on Windows?", "How can I potentially solve the name resolution error encountered during pip install on a Docker container in Windows?", "What command can I use to run a Docker container with a DNS setting to avoid pip install errors on Windows?", "Which programming language version is mentioned in the solution for pip install issues in a Docker container on Windows?"]
# ["How do I fix the issue of ny_taxi_postgres_data being empty after running the Docker script in VS Code?", "What should I do if the Docker ny_taxi_postgres_data folder is empty on Windows?", "Why is the ny_taxi_postgres_data folder empty even after running Docker correctly?", "Is there a solution for an empty ny_taxi_postgres_data in Docker when using VS Code?", "What command can I run to make the ny_taxi_postgres_data files visible on Windows using VS Code?"]
# [
#   "How can I set up Docker on macOS for Module 1?",
#   "Is there a recommended article for setting up Docker on a Mac?",
#   "What should I do if the suggested macOS Docker setup method is outdated?",
#   "Where can I download Docker for macOS if I face issues with the current setup?",
#   "Has anyone confirmed a working method for installing Docker on Mac after the licensing change?"
# ]
# ["How can I fix the 'Operation not permitted' error when changing permissions of /var/lib/postgresql/data?", "What command can I use to create a Docker volume for PostgreSQL data?", "How can I verify the Docker volume is created successfully in Docker Desktop?", "What should I do if I get an error that /var/lib/postgresql/data is not empty while initializing?", "What environment variables need to be set when running PostgreSQL in Docker?"]
# [
#   "How can I resolve the 'invalid reference format' error when mounting volumes with Docker on Windows?",
#   "Are there any specific folder naming conventions I should follow to avoid Docker volume mapping issues on Windows?",
#   "What are the alternative options to replace the '-v' part when trying to mount volumes on Windows in Docker?",
#   "What should I do if Docker automatically creates a folder called 'ny_taxi_postgres_data;C' on Windows?",
#   "What is the recommended way to use volume names instead of paths for Docker on Windows if other options don't work?"
# ]
# ["What should I do if I encounter 'Docker - Error response from daemon: invalid mode: \\Program Files\\Git\\var\\lib\\postgresql\\data'?",
# "What is the correct way to replace the mounting path in Docker?",
# "Can you give an example of correctly mounting a path in Docker?",
# "How do I fix a Docker mounting path error related to Git?",
# "What changes do I need to make when getting an invalid mode error in Docker?"]
# ["Why does Docker give an error when creating buildmount source path '/run/desktop/mnt/host/c/<your path>'?", "What should I do if I see the error message 'file exists' when running a Docker command.", "How can I fix the error in Docker related to mounting on the second run?", "Why shouldn't I mount on the second Docker run?", "What command should I use if I encounter an error with mounting in Docker?"]
# ["What does the Docker build error 'error checking context: 'can't stat <path>'' indicate?",
# "How can I fix the Docker build error caused by permission issues on the directory 'ny_taxi_postgres_data'?",
# "Why does the Docker build error mention a user id change to 999, and how does it affect the build process?",
# "What files are essential for running the docker build command for the 'taxi_ingest:v001' image?",
# "Where can I find a detailed explanation for resolving the Docker build error related to permission issues?"]
# ["What should I do if I see ERRO[0000] error waiting for container: context canceled while using Docker?",
# "What does it mean if I get 'error: unknown command 'status', see 'snap help'.' when checking Docker status?",
# "How can I verify if I installed Docker via snap?",
# "What solution is there if snap gives an unknown command error for Docker?",
# "What is a potential cause for Bind for 0.0.0.0:5432 failed error with Docker?"]
# [
#   "What is the cause of the Docker build error related to checking context for ‘/home/fhrzn/Projects/.../ny_taxi_postgres_data’?",
#   "How can I fix the Docker build error that states ‘can’t stat’ a folder?",
#   "Why does the Docker build error occur on PopOS linux due to folder authorization rights?",
#   "What command can I use to add permissions for everyone to a folder causing Docker build error?",
#   "Can you provide an example of how to use sudo chmod to fix the Docker build error on PopOS?"
# ]
# [
#   "What should I do if I encounter a 'failed to read dockerfile: error from sender: open ny_taxi_postgres_data: permission denied' error on my Ubuntu/Linux system?",
#   "How do I grant permissions on the ny_taxi_postgres_data folder to resolve the permission denied error when building a Docker container?",
#   "What command should I use to change permissions on the ny_taxi_postgres_data folder to fix the Docker build error?",
#   "Why do I get a permission denied error when I try to rebuild the Docker container on my Ubuntu/Linux system?",
#   "What does the chmod -R 755 command do to fix the permission issue with the Docker build process on Linux systems?"
# ]
# [
#   "How can I find the network name in Docker?",
#   "What command lists Docker networks?",
#   "Where can I see the names of all Docker networks?",
#   "How do I list all networks in Docker?",
#   "What is the command to view Docker network names?"
# ]
# [
#     "What should I do when Docker gives an error about the container name 'pg-database' already being in use?",
#     "How can I restart a docker image without removing the existing container?",
#     "If I encounter a conflict with a container name, what are the steps to resolve it?",
#     "What command should I use to stop a running Docker container that has naming conflicts?",
#     "Is there an alternative to removing a Docker container when I want to restart it?"
# ]
# [
#   "What is the cause of the error 'could not translate host name' when using docker-compose?",
#   "What is a typical error I might encounter with Docker and sqlalchemy?",
#   "How can I resolve the 'could not translate host name' error in my ingestion script?",
#   "What should I check when I run 'docker-compose up -d' to fix a database connection issue?",
#   "Can you give an example of how to replace 'pgdatabase' in my Docker setup?"
# ]
# [
#     "How can I install Docker on a MacOS VM running on top of Linux?",
#     "What should I do to enable Docker installation on a Windows 11 VM on a Linux host?",
#     "How do I configure nested virtualization for Docker on an Intel CPU?",
#     "What commands enable nested virtualization for Docker on an AMD CPU?",
#     "Can you provide the steps to configure nested virtualization when using Docker on a VM?"
# ]
# ["How can I manage Docker containers, images, and networks from VS Code?", "Do I need any specific extension for Docker in VS Code?", "Will the Docker extension in VS Code work if Docker runs on WSL2?", "How do I stop a Docker container?", "What is the command syntax to stop a Docker container?"]
# {
#   "questions": [
#     "Why does my PostgreSQL Docker container say the database system is shut down?",
#     "What does it mean when my PostgreSQL Docker logs mention the database directory contains a database?",
#     "Why is my Docker PostgreSQL container not accepting any requests?",
#     "What should I do if the PostgreSQL server terminated abnormally?",
#     "How can I fix the error where the PostgreSQL Docker container connection fails unexpectedly?"
#   ]
# }
# ["How can Docker be installed on certain versions of Ubuntu?", "What command is used to install Docker via snap on Ubuntu?", "Is there an alternative to install Docker on some Ubuntu versions?", "Which package manager can be used to install Docker on some Ubuntu distributions?", "Can you provide the command for installing Docker on specific Ubuntu versions?"]
# [
#   "What should I do if I encounter the error 'could not change permissions of directory /var/lib/postgresql/data: Operation not permitted' when using Docker-Compose?",
#   "How do I define a named volume in a Docker-Compose file?",
#   "What command can I use to inspect a Docker volume to check its location?",
#   "Why did my mounting directory get named incorrectly after running docker compose up, and how can I fix it?",
#   "What steps should I take if the mounting directory created by Docker doesn't use the existing named volume?"
# ]
# ["What should I check if I get the error 'Couldn’t translate host name to address' in Docker-Compose?", "Which command should I use to start Docker containers in detached mode?", "How can I view the currently running containers in Docker?", "How do I view the logs for a specific Docker container?", "What command should I run if 'docker ps' does not show the pg-database container running?"]
# ["How do I resolve the 'could not translate host name \"pg-database\" to address' error in Docker-Compose?",
# "What does the error sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) signify when using Docker-Compose?",
# "Why is Docker-Compose creating its own default network, and how can I find the new network name?",
# "What steps should I take if I lose database data and cannot execute my Ingestion script?",
# "Can alternatives like HeidiSQL or usql be used if problems persist with pgcli in Docker-Compose?"]
# ["What should I do when Docker-Compose returns an error response from daemon stating the network is not found?", "How can I resolve the issue of a hostname not resolving on localhost:8080?", "What are the recommended steps to fix Docker-Compose connectivity issues?", "How should I configure the docker-compose.yml file to ensure proper network specification?", "What is an example configuration for a Docker-Compose file to connect PostgreSQL and PGAdmin4 using a specific network?"]
# [
#     "How do I persist the PGAdmin contents when using docker-compose on GCP?",
#     "Why doesn't Postgres persist its data to the specified path on GCP when using docker-compose?",
#     "What should I do if PGAdmin data persistence isn't working with the mentioned path in docker-compose on GCP?",
#     "Can you explain how to use Docker Volume to ensure PGAdmin data persists in GCP?",
#     "What changes to the docker-compose configuration are needed to persist PGAdmin data using Docker Volume?"
# ]
# ["Why does the Docker engine stop and fail to fetch extensions?",
# "What should I do if Docker keeps crashing even after a restart?",
# "How can I stop the nonstop pop-ups about Docker failing to fetch extensions?",
# "Is there a way to fix Docker without reinstalling it?",
# "What steps should I take if updating Docker doesn't resolve the issue?"]
# [
#     "How do I persist pgAdmin configuration in Docker-compose?",
#     "What is the purpose of the volumes section when configuring pgAdmin in Docker-compose?",
#     "What environment variables are needed for pgAdmin in Docker-compose?",
#     "What steps are necessary before running docker-compose up for persisting pgAdmin settings?",
#     "How do I set the correct permissions for the pgAdmin_data folder in Docker?"
# ]
# [
#   "How can I resolve the 'dial unix /var/run/docker.sock: connect: permission denied' error in Docker-Compose?",
#   "What steps should I follow if I face permission issues with Docker-Compose?",
#   "How can I make pgAdmin maintain its state and remember previous connections?",
#   "What volume configuration should I add to my docker-compose.yaml file to save pgAdmin state?",
#   "What do I need to do after adding volumes to the pgAdmin declaration in docker-compose.yaml?"
# ]
# ["What should I do if docker-compose is still not available after modifying .bashrc in my Google Cloud VM?", "When following the video tutorial 1.4.1, why doesn't the docker-compose command work as expected?", "How can I make the docker-compose command more convenient to use after installation in the Google Cloud VM?", "Why is the docker-compose file named differently after downloading from GitHub, and how can I resolve this?", "Is there a step I missed in renaming the docker-compose file to make it functional?"]
# ["What should I do if I encounter an error getting credentials after running docker-compose up -d?", "How can I resolve Docker-Compose credential errors?", "What package do I need to install to fix the credentials error in Docker-Compose?", "Is there a specific command to install something to solve Docker-Compose credential issues?", "Where can I find more information about the Docker-Compose credential error?"]
# ["What should I do if I am facing errors with Docker Compose and pgadmin setup in Module 1?",
# "What steps are needed to create a new volume on Docker?",
# "How should I modify my docker-compose.yml file for proper setup?",
# "What should be done when importing the CSV file for data ingestion?",
# "In what order should I execute the setup steps for Docker and pgadmin?"]
# [
#   "Where can I find the config.json file for Docker to fix the 'docker-credential-desktop' executable not found error?",
#   "What should I modify in the Docker config.json file to resolve the credentials error?",
#   "How can I address the 'exec: docker-credential-desktop not found in %PATH%' issue using Docker Compose?",
#   "What is the correct modification to stop Docker from displaying 'error getting credentials'?",
#   "What steps should I follow after modifying the credentials store setting in Docker's config.json?"
# ]
# ["Which binary should I download for Docker-Compose in WSL?", "How can I verify the system type for Docker-Compose?", "What command returns the system flavor for Docker-Compose installation?", "Where can I find the correct Docker-Compose binary?", "Is there a quick command to download Docker-Compose for my system?"]
# ["How do I fix the 'undefined volume' error in Docker-Compose on Windows/WSL?",
# "I wrote my docker-compose.yaml file like the video, why am I getting an undefined volume error?",
# "What should I do if my 'pgdatabase' service refers to an undefined volume in Docker-Compose?",
# "How can I resolve the 'invalid compose project' error related to volumes in Docker-Compose?",
# "In Docker-Compose, where should I add the volumes section to fix an undefined volume error?"]
# [
#   "What causes the Docker directory permissions error in WSL?",
#   "How can I resolve Docker directory permissions errors when using WSL?",
#   "Why should Docker volumes be used for storage instead of local drives in WSL?",
#   "Is the 'user:' field necessary when using Docker volumes with WSL?",
#   "What are the benefits of using Docker volumes over local drives?"
# ]
# [
#   "What should I do if I can't use pgadmin to query Postgres in Docker?",
#   "Why doesn't pgadmin work easily for querying Postgres?",
#   "What libraries are needed if pgadmin doesn't work for querying in Postgres?",
#   "Is there an alternative to using pgadmin for querying Postgres in Docker?",
#   "How can I install the required library for Postgres querying in Docker?"
# ]
# ["What causes the error 'Insufficient system resources exist to complete the requested service' in WSL?", "How can I update Windows Terminal to fix WSL errors?", "Where can I check for pending Windows Security updates to resolve WSL issues?", "What should I do after updating Windows Terminal and Security updates to fix WSL?", "How do I find the library of apps installed on my system in Microsoft Store?"]
# ["How can I fix the WSL integration issue with Ubuntu stopping unexpectedly with exit code 1?", "What should I do if the same WSL issue reappears after restarting?", "Can you explain the steps to fix the DNS issue for WSL on Windows?", "What is an alternative method to solve the WSL integration problem without using the registry?", "Why does the terminal show 'conda: command not found' when using WSL?"]
# ["What should I do if WSL2 isn’t looking for .ssh keys in the correct folder?", "How can I fix the error when trying to run the GPC VM through SSH via WSL2?", "What is the command to change permissions for the private key SSH file?", "How do I create a .ssh folder in the home directory of WSL2?", "What command should I use to copy the content of the Windows .ssh folder to the new WSL2 .ssh folder?"]
# ["How can I fix the issue of WSL2 not resolving the host name?",
#  "What steps should I follow to create a config file for WSL2 in the correct location?",
#  "Where should I create the .ssh folder in WSL2 to resolve the host name issue?",
#  "What details need to be included in the config file to reference the correct path in WSL2?",
#  "Why is WSL2 failing to reference the correct .ssh/config path from Windows?"]
# [
#   "What should I do if I'm getting a connection refused error when using PGCLI on port 5432?",
#   "How can I resolve the issue of 'could not receive data from server' while using PGCLI?",
#   "What command should I use to connect to the PostgreSQL database if the port 5432 connection fails?",
#   "Why might the PGCLI command to connect to port 5432 refuse the connection?",
#   "Can you provide a correct PGCLI command to connect to a PostgreSQL database on port 5432?"
# ]
# [
#     "What should I do if I receive a --help error with PGCLI?",
#     "Could an installation error cause PGCLI to have problems?",
#     "Where can I find help for installation errors with PGCLI?",
#     "Is it common to encounter errors with PGCLI if there's an installation problem?",
#     "What might be causing a --help error message when using PGCLI?"
# ]
# [
#   "Do we need to run pgcli from another Docker container in Module 1?",
#   "How do we access the PostgreSQL database using pgcli in this section?",
#   "Is it necessary to map pgcli to a Docker container in Module 1?",
#   "Can we use pgcli directly on our computer for PostgreSQL access?",
#   "What port is mapped for PostgreSQL access in this section of the course?"
# ]
# ["Why am I getting a FATAL: password authentication failed for user 'root' error with PGCLI in Module 1?",
#  "What can I do if I have a local Postgres and see a 'password authentication failed' error?",
#  "How do I use a different port to resolve Postgres authentication issues in Docker?",
#  "What command do I use to connect to my Postgres Docker container using pgcli?",
#  "How can I find and stop a service blocking port 5432 on MacOS to fix Postgres issues?"]
# ["How should I install pgcli to avoid PermissionError: [Errno 13]?", "What should I do if the conda install for pgcli is stuck at 'Solving environment'?", "Why do I receive a PermissionError when running pgcli as shown in the traceback?", "Which directory caused the PermissionError in pgcli according to the traceback?", "Is it recommended to use sudo for installing pgcli?"]
# [
# "What error does PGCLI show when the pq wrapper is not available?",
# "What is the recommended Python version to avoid 'psycopg2-binary' installation issues?",
# "How can I check my current Python version?",
# "What command creates a new conda environment with Python 3.9?",
# "What is the specific pip command to install the 'psycopg2_binary' package?"
# ]
# [
# "How can I resolve the issue if my Bash prompt is stuck on the password command for postgres in PGCLI?",
# "What should I do if I encounter the error 'password authentication failed for user root' while using PGCLI?",
# "What are the alternatives to resolve the password prompt issue in PGCLI on a Windows machine?",
# "How can I use WSL to resolve the password authentication failed error in PGCLI?",
# "What should I do to ensure the database remains connected while working with the Postgres:13 image in Docker?"
# ]
# ["How do I fix the issue where pgcli command is not recognized on Git bash?", "What solution is suggested for Windows Terminal not recognizing the pgcli command?", "How can I find the Python path to add to Windows PATH for pgcli?", "Why might pgcli not be found even after installing it?", "What is an example Python path to add to the System Variables for pgcli recognition?"]
# [
#   "How can I run pgcli without installing it locally?",
#   "What is the command to run pgcli in a Docker container?",
#   "What values do I need to set for network name, hostname, username, port, and database name to use pgcli in Docker?",
#   "What should I do if I encounter issues running pgcli locally?",
#   "Can you provide an example Docker command to run pgcli with PostgreSQL?"
# ]
# [
#   "In Module 1, should I use quotations around columns with capital letters in PGCLI?",
#   "Why does PULocationID not get recognized in PGCLI, but 'PULocationID' does?",
#   "Can you explain why unquoted local identifiers are case insensitive in Docker and Terraform?",
#   "What is the correct way to reference a column with capital letters in PGCLI?",
#   "Where can I find more information about the case sensitivity of local identifiers?"
# ]
# ["What should I do if I get the error column c.relhasoids does not exist when using PGCLI?", "How can I resolve the issue where the command \\d gives an error about c.relhasoids in PGCLI?", "What steps are required to fix the PGCLI error about c.relhasoids?", "How do I reinstall PGCLI to fix the c.relhasoids error?", "What actions should be taken if PGCLI reports that c.relhasoids does not exist?"]
# ["Why does psycopg2 give an OperationalError for password authentication failed for user 'root'?", "What is the cause for a connection to Postgres at localhost failing with a FATAL error?", "How do I resolve a Postgres port conflict error when using Docker?", "What should I do if the default Postgres port 5432 is already in use?", "How can stopping a service in Windows help with a Postgres connection issue?"]
# ["What should I do if I get a 'role root does not exist' error while using pgcli to connect to Postgres?", "How can I resolve the 'FATAL: role root does not exist' error when connecting to Postgres through Jupyter Notebook?", "What could be the reason for the 'connection to server at localhost failed' error when Postgres is already installed?", "How can I verify if there is a root user in my Postgres container that can log in?", "What steps should I follow if 'docker compose down' and removing the Postgres volume folder doesn't work?"]
# [
#   "What should I do if I get an OperationalError saying database 'ny_taxi' does not exist?",
#   "How can I check if postgres is running to fix the connection issue?",
#   "What is a potential solution if I already have postgres installed and I encounter a port conflict?",
#   "Why am I receiving a psycopg2.OperationalError related to the 'ny_taxi' database?",
#   "How can building an instance on a different port help with the connection problem?"
# ]
# [
#   "What should I do if I encounter a ModuleNotFoundError for 'psycopg2' while working with Postgres in Module 1?",
#   "How can I install the psycopg2-binary package in the Docker and Terraform module?",
#   "What steps should I follow if I get a ModuleNotFoundError for 'psycopg2' even after installing the psycopg2-binary package?",
#   "What command updates conda to potentially resolve issues with the 'psycopg2' module?",
#   "If I am using a Mac and facing an error with psycopg2 showing pg_config not found, what should I do?"
# ]
# [
#   "Why do I get a 'Column does not exist' error in Pyscopg2 on my MacBook Pro M2 when using Postgres?",
#   "What is the solution for the 'Column does not exist' error in join queries in Postgres on a MacBook Pro M2?",
#   "How should column names be enclosed in join queries to avoid the 'Column does not exist' error in Postgres?",
#   "Why does enclosing column names in single quotes cause an error in join queries in Pyscopg2 on MacBook Pro M2?",
#   "What should I do differently in join queries to fix the 'Column does not exist' error in Postgres on Mac?"
# ]
# [
#     "Why does the create server dialog not show up in pgAdmin?",
#     "Is there a new method to create a server in pgAdmin?",
#     "How can I register a server in the updated pgAdmin?",
#     "What should I do if the create server option is missing in pgAdmin?",
#     "Has the process for setting up a server changed in pgAdmin's new version?"
# ]
# ["What can be done to fix the blank or white screen that appears after logging into pgAdmin using GitHub Codespaces in the browser?",
#  "What error message appears in the terminal when pgAdmin shows a blank screen after login in the browser?",
#  "How can I modify the docker run command to set the environment variable that prevents the blank screen issue in pgAdmin?",
#  "What environment variable needs to be set to prevent the blank screen issue in pgAdmin when using GitHub Codespaces in the browser?",
#  "Does the blank screen issue with pgAdmin occur when using GitHub Codespaces in the locally installed VSCode?"]
# [
#     "How can I fix the issue where I cannot access the PgAdmin address via my browser on a Mac Pro?",
#     "What modifications can I make to the 'docker run' command to access the PgAdmin address?",
#     "How should I configure docker-compose.yaml to successfully access the PgAdmin address?",
#     "What is the solution for the 'ModuleNotFoundError: No module named 'pysqlite2'' error when using Anaconda?",
#     "Where should I copy the sqlite3.dll file to resolve the ImportError related to _sqlite3 in Anaconda?"
# ]
# ["Why am I missing 100000 records when rerunning the ingestion script in Jupyter notebook?", "How do I ingest all the data into the table yellow_taxi_data as shown in video 1.2.2?", "What causes the missing records when running the ingestion script a second time from top to bottom?", "What is the solution to ensure the first chunk of 100000 records is not missed?", "Was the Jupyter notebook intended to be run top to bottom?"]
# ["How can I iterate through a CSV file without errors in Python?",
# "Which library is recommended for reading a CSV file in Python?",
# "What is the command to unzip gzip files on a local or virtual Ubuntu machine?",
# "Can gzip compressed CSV files be unzipped using the 'unzip' command?",
# "Do I need to install any tools to unzip gzip files on Ubuntu?"]
# [
#   "How can I use Pandas to read column values as dates directly from a CSV file?",
#   "What parameter should I use in read_csv to interpret strings as datetime?",
#   "Could you provide an example of parsing dates with read_csv as shown in week 1?",
#   "What is the datatype of the 'tpep_pickup_datetime' column in the given example?",
#   "How many entries does the DataFrame 'yellow_tripdata_2021-01.csv' have in the example?"
# ]
# ...
#   "What is the cause of the unexpected error encountered by mlflow.pyfunc?",
#   "How can the memory issue in the mlflow lambda function be diagnosed?",
#   "What is a recommended fix for memory allocation issues in a lambda function using mlflow?"
# ]
# ["What is the connection between the video and the notebook in Module 4?", "Should I follow the video or the notebook for Module 4?", "What does the notebook in Module 4 eventually use?", "Is it necessary to be patient while following the video in Module 4?", "Who provided the note about the video and notebook in Module 4?"]
# ["How should I pass AWS environment variables to my Docker image?",
#  "What was the mistake when trying to run the Docker image with AWS credentials?",
#  "Can I set AWS credentials using environment variables and if so, how?",
#  "How can I use AWS configuration files with Docker for credential access?",
#  "Who added the solution for passing AWS credentials via Docker environment variables?"]
# [
# "How can I view the model inside the docker container within the app directory?",
# "What is the first step to see the model listed on the image svizor/zoomcamp-model:mlops-3.10.0-slim?",
# "What command should I use to build the Docker image after creating the Dockerfile?",
# "Where should the 'CMD' command be placed to run a script in the docker container?",
# "Why is a build needed every time I change the Dockerfile?"
# ]
# ["How do I resolve the warning about image's platform not matching the host?",
# "What command should I use to build a docker image for arm64?",
# "Why am I seeing a warning about linux/amd64 and linux/arm64/v8?",
# "Can you show a command example for building a Docker image with a specific platform?",
# "What’s the solution for a platform mismatch warning when building Docker images?"]
# [
#   "What should I do if I encounter an HTTP 403 error when calling apply_model() in score.ipynb?",
#   "How can I fix the HTTP Error 403: Forbidden when processing data in score.ipynb?",
#   "What is the solution to the HTTPError: HTTP Error 403: Forbidden in Module 4: Deployment?",
#   "Who should I contact for issues related to HTTP Error 403 during the apply_model() call in score.ipynb?",
#   "Where should I change the input_file URL to resolve the HTTP 403 error in Module 4: Deployment?"
# ]
# ["What command resolves the error 'ModuleNotFoundError: No module named pipenv.patched.pip._vendor.urllib3.response'?", "How can I fix the error related to 'site-packages\\pipenv\\patched\\pip\\_vendor\\urllib3\\connectionpool.py'?", "Which command should I use to reinstall pipenv to resolve a ModuleNotFoundError?", "What combination of commands can I use to update pip and fix urllib3 connection pool issues?", "Who provided the solution to reinstall pipenv and update pip to resolve these errors?"]
# ["What should I do if prompted for credentials when accessing Grafana in Module 5?", "How do I resolve the issue of being asked for a username and password at http://localhost:3000/ after running docker-compose up?", "What are the default login credentials for Grafana as shown in video 5.2?", "How can I set a new password in Grafana after the initial login?", "Who provided the solution for the login window issue in Grafana?"]
# ["What might cause services not to start when running docker compose up --build in Linux in Module 5?", "How can I resolve the unknown flag: --build error during monitoring setup in Linux in Module 5?", "What is the correct command to start services using docker-compose according to video 5.2?", "Why do I get an unknown flag error when following the instructions in video 5.2 for Linux?", "Who provided the solution for the monitoring error issue in Module 5's video 5.2?"]
# ["Why am I getting a KeyError ‘content-length’ when I run prepare.py?", "What should I do if the link in prepare.py to download taxi data does not work anymore?", "How can I fix the issue with KeyError ‘content-length’ in prepare.py?", "Is there a new link to download the taxi data in prepare.py?", "What changes should I make in prepare.py to avoid the KeyError ‘content-length’ issue?"]
# ["What should I do if I receive 'Max retries exceeded with url: /api' when running 'docker-compose up –build'?", "What does 'service exit with code 2' mean in the context of the evidently service?", "How can I resolve the import error 'from pyarrow import parquet as pq' in app.py of the evidently service?", "Is there an alternative solution if 'pip install pyarrow' doesn't resolve the issue with 'app.py'?", "What should I do if restarting my machine doesn't fix the evidently service exit with code 2 issue?"]
# [
#   "What might cause a ValueError when using evidently in Module 5?",
#   "How do I fix a 'ValueError: Incorrect item' error in Module 5?",
#   "What should I add to avoid 'ValueError' when passing metrics in Module 5?",
#   "Can a missing set of parentheses cause an error in Module 5's evidently?",
#   "Who provided the solution to the error in Module 5: Monitoring?"
# ]
# [
#     "What should I do if I get an error with RegressionQualityMetric() in Module 5?",
#     "How do I avoid errors when using RegressionQualityMetric() in Module 5?",
#     "Why is target='duration_min' necessary in RegressionQualityMetric() in Module 5?",
#     "What is required in current_data for RegressionQualityMetric() to work in Module 5?",
#     "What happens if target='duration_min' is not added in RegressionQualityMetric() in Module 5?"
# ]
# ["Why does the error 'Found array with 0 sample(s)' occur in module 5?", "What causes the training dataset to be empty in module 5?", "How can I fix the ValueError related to 0 samples in LinearRegression?", "What adjustment should I make to the beginning date to prevent an empty array error?", "Who contributed the solution for the 'Found array with 0 sample(s)' problem in module 5?"]
# ["What error do I encounter after adding a metric in Module 5?",
#
# "What should I do when getting 'target columns' and 'prediction columns' not present errors?",
#
# "What is the first step to fix the error in adding a metric?",
#
# "Can you give an example of a metric that doesn’t require parameters in Module 5?",
#
# "Who provided the solution for the error encountered in Module 5?"]
# ["What should I do if I can't log in to Grafana with the default admin/admin credentials?",
# "How can I fix an error when logging into Grafana with standard requisites?",
# "What command should I run to reset the admin password in Grafana?",
# "Who provided the solution for the Grafana login issue?",
# "What error occurs when using admin/admin in Grafana login and how can it be resolved?"]
# ["How can I fix my Grafana charts when they don’t update even though my metric generation script is running?",
#  "What should be the refresh interval for Grafana charts to ensure they get frequent updates?",
#  "What timezone should I set in Grafana if it currently doesn’t update and is using 'Europe/London'?",
#  "Why might Grafana charts not update despite the metric generation script running constantly?",
#  "What two key settings need adjustment if Grafana charts are not getting updated?"]
# ["What should I do if the Prefect server stops immediately after running `prefect server start`?",
#  "What can I use as an alternative if my Prefect server isn't running locally?",
#  "Where did Erick Calderin report the issue of the Prefect server not running locally?",
#  "Why did the Prefect server stop immediately after running the start command?",
#  "What is a potential solution if Prefect server stops immediately, according to Erick Calderin?"]
# [
# "What should I do when encountering a 'no disk space left' error with docker compose up?",
# "How can I resolve a disk space issue in Docker using the CLI?",
# "What Docker command helps clear unused resources like build cache and images?",
# "How do I check what is taking up disk space in Docker before pruning?",
# "Which Docker command provides details on disk usage by unused resources?"
# ]
# ["What should I do if I see the error 'Failed to listen on :::8080' when running docker-compose up?", "How can I solve the issue with 'php_network_getaddresses: getaddrinfo failed: Address family for hostname not supported'?", "What command should I add to the adminer block in the yml file to fix the listen error on port 8080?", "Where should I place 'php -S 0.0.0.0:8080 -t /var/www/html' to address the error during docker-compose build?", "Who can I contact for help if adding the command to the adminer block does not solve my problem?"]
# ["How can we generate Evidently-style charts inside Grafana?",
# "What type of panel should we use in Grafana to generate a scatter plot?",
# "Is there a quick way to recreate the Evidently dashboard natively in Grafana?",
# "How can we export Evidently output externally to create visualizations?",
# "What would be more useful during debugging for under- and over-performance segments?"]
# ["How can I solve the 'Unable to locate credentials' error when running localstack with kinesis?",
# "What should I do if I see the ‘Unable to locate credentials’ error in test_docker.py after running localstack with kinesis?",
# "What environment variables need to be added to the docker-compose.yaml file to fix the credentials error?",
# "Can I use any values for AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY in docker-compose.yaml?",
# "What are the steps to configure AWS credentials for localstack using the aws command?"]
# ["Why do I get an error with the message 'unspecified location constraint is incompatible' when using localstack and boto3?", "How can I resolve the IllegalLocationConstraintException error when creating a bucket in a region-specific endpoint using boto3?", "What is the cause of the IllegalLocationConstraintException error when calling CreateBucket with localstack?", "What should I change in my boto3 create_bucket call to avoid the 'unspecified location constraint is incompatible' error?", "How do I include a location constraint when creating a bucket in boto3 to prevent errors?"]
# ["What should I do if I see the error <botocore.awsrequest.AWSRequest object at 0x7fbaf2666280> when running an AWS CLI command?", "How can I resolve an error that occurs when running aws s3 ls in AWS CLI?", "What environment variables need to be set to fix the <botocore.awsrequest.AWSRequest object at 0x7fbaf2666280> error?", "Is there any specific value required for AWS_DEFAULT_REGION, AWS_ACCESS_KEY_ID, and AWS_SECRET_ACCESS_KEY to fix the AWS CLI error?", "Who provided the solution for the <botocore.awsrequest.AWSRequest object at 0x7fbaf2666280> error in the AWS CLI?"]
# [
#     "Why does Pre-commit trigger an error saying 'mapping values are not allowed in this context' at every commit?",
#     "What should I check if pre-commit hooks are not running?",
#     "How can I fix the 'mapping values are not allowed in this context' error during commits?",
#     "What is a common mistake in .pre-commit-config.yaml that causes errors?",
#     "Who added the troubleshooting tip for the Pre-commit error in Module 6?"
# ]
# ["How can I reconfigure pytest if there's no option to remove tests?", "What should I do if I want to reset pytest after testing in a previous folder?", "How can I start over with pytest testing in a new folder?", "Is there a way to remove pytest configurations after finishing tests in a previous folder?", "What steps are required to delete pytest settings from a previously used folder?"]
# [
# "At what point in video 6.3 does the get records command return empty Records?",
# "How can I resolve the issue of empty records when using the get records command in Kinesis?",
# "What flag should be included in the Kinesis get records call to prevent signing requests?",
# "In which module and section is the issue of empty records in Kinesis discussed?",
# "What is the endpoint URL used in the solution for fixing the empty records problem in Kinesis?"
# ]
# ["What error does 'Git commit' raise in Powershell after creating a pre-commit YAML file?",
# "What is the cause of the InvalidConfigError described in Module 6?",
# "How do you set utf-8 encoding when creating a pre-commit YAML file in Powershell?",
# "Who added the solution for the utf-8 encoding error in the FAQ record?",
# "What command can be used to create a pre-commit YAML file with utf-8 encoding in Powershell?"]
# ["What should I do if I encounter a 'PythonInfo' object has no attribute 'version_nodot' error during a git commit with a pre-commit hook?",
# "How can I resolve the error message 'AttributeError: 'PythonInfo' object has no attribute 'version_nodot' when trying to commit?",
# "What is the solution for fixing a CalledProcessError due to 'version_nodot' attribute missing in pre-commit?",
# "Why does git commit with pre-commit hook fail with a 'PythonInfo' object has no attribute 'version_nodot' error?",
# "How do I clear app-data of the virtualenv to resolve 'PythonInfo' object has no attribute 'version_nodot' error?"]
# ["How can I resolve the 'module not found' error when using custom packages with pytest?",
# "What is the correct command to run pytest without encountering module import errors?",
# "Why does running pytest fail with a 'No module named' error for custom packages?",
# "Can I export PYTHONPATH to fix module not found errors with pytest?",
# "Why does pytest not find modules while running tests, but running the Python script directly works?"]
# ["What is the cause of the 'No module named production' error when calling pytest hook during git commit?", "How should the project structure look to avoid the 'module not found' issue with pre-commit hooks?", "What should the entry command be to fix the pytest 'module not found' error when using custom packages?", "What environment setting is necessary in the run.sh script to ensure pytest runs correctly with custom packages?", "Which repository and language should be used in the hook configuration to resolve the 'module not found' error?"]
# [
#     "What should I do if I get a permission denied error while running a script in GitHub Actions?",
#     "What is the error code for a permission error in GitHub CI actions?",
#     "What command can I use to add execution permission to a script file in GitHub?",
#     "Which step in the CI YML file definition might cause a permission error?",
#     "Who added the solution for the permission denied error in Module 6?"
# ]
# ["What issue does managing multiple Docker containers with docker-compose aim to address?",
# "How can we handle multiple container services efficiently in a docker-compose file?",
# "What is the syntax to add profiles to a service definition in a docker-compose file?",
# "What command should be used to start a service with a specific profile in Docker Compose?",
# "Who provided the solution for managing multiple Docker containers with profiles in Module 6?"]
# ["What should I check if I am having issues with integration tests and kinesis in Module 6?",
# "Why is it important for AWS regions to match in docker-compose and local config?",
# "How can I fix problems related to AWS regions while running integration tests?",
# "What specific settings should the ~/.aws/config file and docker-compose.yaml have for region matching?",
# "Who provided the solution for ensuring AWS regions match in docker-compose and local config?"]
# ["What should I do if pre-commit command fails with isort repository?", "Which version of isort should be set to avoid pre-commit failure?", "Who added the solution for the pre-commit command issue with isort?", "What module covers best practices including pre-commit commands?", "How to resolve pre-commit command failure with isort repository?"]
# ["How can infrastructure created by GitHub Actions in AWS be destroyed?",
# "What is the problem description for destroying infrastructure using GitHub Actions?",
# "Which Terraform command should be run locally to initialize the backend for destroying infrastructure?",
# "Which Terraform command should be used along with a variable file to destroy infrastructure?",
# "Who added the solution for destroying infrastructure created via GitHub Actions?"]

# %%
import pickle

with open('results.pkl', 'wb') as archivo:
    pickle.dump(results, archivo)

# %%
import pandas as pd

# %%
df = pd.DataFrame(final_results, columns=['question', 'course', 'document'])

# %%
df
# Out:
#        question                     course  document
# 0             [  data-engineering-zoomcamp  c02e79ef
# 1            \n  data-engineering-zoomcamp  c02e79ef
# 2                data-engineering-zoomcamp  c02e79ef
# 3                data-engineering-zoomcamp  c02e79ef
# 4             "  data-engineering-zoomcamp  c02e79ef
# ...         ...                        ...       ...
# 389497        n             mlops-zoomcamp  886d1617
# 389498        s             mlops-zoomcamp  886d1617
# 389499        ?             mlops-zoomcamp  886d1617
# 389500        "             mlops-zoomcamp  886d1617
# 389501        ]             mlops-zoomcamp  886d1617
#
# [389502 rows x 3 columns]

# %%
df.to_csv('ground-truth-data.csv', index=False)
